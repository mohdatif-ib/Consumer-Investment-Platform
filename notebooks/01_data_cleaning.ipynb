# %% [markdown]
# # 01 Data Cleaning
#
# Load raw startup funding data, clean missing values, standardize dates/currencies, remove duplicates, and create analytical tables.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from consumer_brand_intel.data_cleaning import load_csv_files, clean_raw_funding_data, build_analytical_tables, save_cleaned_tables

raw_path = PROJECT_ROOT / 'data' / 'raw' / 'startup_funding_sample.csv'
processed_dir = PROJECT_ROOT / 'data' / 'processed'

# %%
raw = load_csv_files([raw_path])
raw.head()

# %%
cleaned = clean_raw_funding_data(raw)
cleaned[['company_name', 'sector', 'funding_date', 'funding_stage', 'amount_usd']].head()

# %%
tables = build_analytical_tables(cleaned)
save_cleaned_tables(tables, processed_dir)
tables.metrics
